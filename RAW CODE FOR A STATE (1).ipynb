# %%
import numpy as np
import pandas as pd
import json
from pandas.io.json import json_normalize

# %%
df1=pd.read_json("C:/Users/basha/OneDrive/Desktop/transaction/hover/country/india/state/andaman-_-nicobar-islands/2018/1.json")
data1 = df1.iloc[0].to_json()
data1 = pd.read_json(data1)
data1['year']=2018
data1["state"]="Andaman-_-nicobar-islands"
data1["quarter"]="q1"
data1 = data1[['data','year','state','quarter']]
df = data1
df['name'] = df['data'].apply(lambda x:x['name'])
df['type'] = df['data'].apply(lambda x:x['metric'][0]['type'])
df['count'] = df['data'].apply(lambda x:x['metric'][0]['count'])
df['amount'] = df['data'].apply(lambda x:round(x['metric'][0]['amount']))
ani1 = df.iloc[:,1:]


df1 = pd.read_json("C:/Users/basha/OneDrive/Desktop/transaction/hover/country/india/state/andaman-_-nicobar-islands/2018/2.json")
data1 = df1.iloc[0].to_json()
data1 = pd.read_json(data1)
data1['year']=2018
data1["state"]="Andaman-_-nicobar-islands"
data1["quarter"]="q2"
data1 = data1[['data','year','state','quarter']]
df = data1
df['name'] = df['data'].apply(lambda x:x['name'])
df['type'] = df['data'].apply(lambda x:x['metric'][0]['type'])
df['count'] = df['data'].apply(lambda x:x['metric'][0]['count'])
df['amount'] = df['data'].apply(lambda x:round(x['metric'][0]['amount']))
ani2= df.iloc[:,1:]


df1 = pd.read_json("C:/Users/basha/OneDrive/Desktop/transaction/hover/country/india/state/andaman-_-nicobar-islands/2018/3.json")
data1 = df1.iloc[0].to_json()
data1 = pd.read_json(data1)
data1['year']=2018
data1["state"]="Andaman-_-nicobar-islands"
data1["quarter"]="q3"
data1 = data1[['data','year','state','quarter']]
df = data1
df['name'] = df['data'].apply(lambda x:x['name'])
df['type'] = df['data'].apply(lambda x:x['metric'][0]['type'])
df['count'] = df['data'].apply(lambda x:x['metric'][0]['count'])
df['amount'] = df['data'].apply(lambda x:round(x['metric'][0]['amount']))
ani3 = df.iloc[:,1:]


df1 = pd.read_json("C:/Users/basha/OneDrive/Desktop/transaction/hover/country/india/state/andaman-_-nicobar-islands/2018/4.json")
data1 = df1.iloc[0].to_json()
data1 = pd.read_json(data1)
data1['year']=2018
data1["state"]="Andaman-_-nicobar-islands"
data1["quarter"]="q4"
data1 = data1[['data','year','state','quarter']]
df = data1
df['name'] = df['data'].apply(lambda x:x['name'])
df['type'] = df['data'].apply(lambda x:x['metric'][0]['type'])
df['count'] = df['data'].apply(lambda x:x['metric'][0]['count'])
df['amount'] = df['data'].apply(lambda x:round(x['metric'][0]['amount']))
ani4= df.iloc[:,1:]



df1 = pd.read_json("C:/Users/basha/OneDrive/Desktop/transaction/hover/country/india/state/andaman-_-nicobar-islands/2019/1.json")
data1 = df1.iloc[0].to_json()
data1 = pd.read_json(data1)
data1['year']=2019
data1["state"]="Andaman-_-nicobar-islands"
data1["quarter"]="q1"
data1 = data1[['data','year','state','quarter']]
df = data1
df['name'] = df['data'].apply(lambda x:x['name'])
df['type'] = df['data'].apply(lambda x:x['metric'][0]['type'])
df['count'] = df['data'].apply(lambda x:x['metric'][0]['count'])
df['amount'] = df['data'].apply(lambda x:round(x['metric'][0]['amount']))
ani5 = df.iloc[:,1:]


df1 = pd.read_json("C:/Users/basha/OneDrive/Desktop/transaction/hover/country/india/state/andaman-_-nicobar-islands/2019/2.json")
data1 = df1.iloc[0].to_json()
data1 = pd.read_json(data1)
data1['year']=2019
data1["state"]="Andaman-_-nicobar-islands"
data1["quarter"]="q2"
data1 = data1[['data','year','state','quarter']]
df = data1
df['name'] = df['data'].apply(lambda x:x['name'])
df['type'] = df['data'].apply(lambda x:x['metric'][0]['type'])
df['count'] = df['data'].apply(lambda x:x['metric'][0]['count'])
df['amount'] = df['data'].apply(lambda x:round(x['metric'][0]['amount']))
ani6= df.iloc[:,1:]


df1 = pd.read_json("C:/Users/basha/OneDrive/Desktop/transaction/hover/country/india/state/andaman-_-nicobar-islands/2019/3.json")
data1 = df1.iloc[0].to_json()
data1 = pd.read_json(data1)
data1['year']=2019
data1["state"]="Andaman-_-nicobar-islands"
data1["quarter"]="q3"
data1 = data1[['data','year','state','quarter']]
df = data1
df['name'] = df['data'].apply(lambda x:x['name'])
df['type'] = df['data'].apply(lambda x:x['metric'][0]['type'])
df['count'] = df['data'].apply(lambda x:x['metric'][0]['count'])
df['amount'] = df['data'].apply(lambda x:round(x['metric'][0]['amount']))
ani7 = df.iloc[:,1:]


df1 = pd.read_json("C:/Users/basha/OneDrive/Desktop/transaction/hover/country/india/state/andaman-_-nicobar-islands/2019/4.json")
data1 = df1.iloc[0].to_json()
data1 = pd.read_json(data1)
data1['year']=2019
data1["state"]="Andaman-_-nicobar-islands"
data1["quarter"]="q4"
data1 = data1[['data','year','state','quarter']]
df = data1
df['name'] = df['data'].apply(lambda x:x['name'])
df['type'] = df['data'].apply(lambda x:x['metric'][0]['type'])
df['count'] = df['data'].apply(lambda x:x['metric'][0]['count'])
df['amount'] = df['data'].apply(lambda x:round(x['metric'][0]['amount']))
ani8= df.iloc[:,1:]




df1 = pd.read_json("C:/Users/basha/OneDrive/Desktop/transaction/hover/country/india/state/andaman-_-nicobar-islands/2020/1.json")
data1 = df1.iloc[0].to_json()
data1 = pd.read_json(data1)
data1['year']=2020
data1["state"]="Andaman-_-nicobar-islands"
data1["quarter"]="q1"
data1 = data1[['data','year','state','quarter']]
df = data1
df['name'] = df['data'].apply(lambda x:x['name'])
df['type'] = df['data'].apply(lambda x:x['metric'][0]['type'])
df['count'] = df['data'].apply(lambda x:x['metric'][0]['count'])
df['amount'] = df['data'].apply(lambda x:round(x['metric'][0]['amount']))
ani9 = df.iloc[:,1:]


df1 = pd.read_json("C:/Users/basha/OneDrive/Desktop/transaction/hover/country/india/state/andaman-_-nicobar-islands/2020/2.json")
data1 = df1.iloc[0].to_json()
data1 = pd.read_json(data1)
data1['year']=2020
data1["state"]="Andaman-_-nicobar-islands"
data1["quarter"]="q2"
data1 = data1[['data','year','state','quarter']]
df = data1
df['name'] = df['data'].apply(lambda x:x['name'])
df['type'] = df['data'].apply(lambda x:x['metric'][0]['type'])
df['count'] = df['data'].apply(lambda x:x['metric'][0]['count'])
df['amount'] = df['data'].apply(lambda x:round(x['metric'][0]['amount']))
ani10= df.iloc[:,1:]


df1 = pd.read_json("C:/Users/basha/OneDrive/Desktop/transaction/hover/country/india/state/andaman-_-nicobar-islands/2020/3.json")
data1 = df1.iloc[0].to_json()
data1 = pd.read_json(data1)
data1['year']=2020
data1["state"]="Andaman-_-nicobar-islands"
data1["quarter"]="q3"
data1 = data1[['data','year','state','quarter']]
df = data1
df['name'] = df['data'].apply(lambda x:x['name'])
df['type'] = df['data'].apply(lambda x:x['metric'][0]['type'])
df['count'] = df['data'].apply(lambda x:x['metric'][0]['count'])
df['amount'] = df['data'].apply(lambda x:round(x['metric'][0]['amount']))
ani11 = df.iloc[:,1:]


df1 = pd.read_json("C:/Users/basha/OneDrive/Desktop/transaction/hover/country/india/state/andaman-_-nicobar-islands/2020/4.json")
data1 = df1.iloc[0].to_json()
data1 = pd.read_json(data1)
data1['year']=2020
data1["state"]="Andaman-_-nicobar-islands"
data1["quarter"]="q4"
data1 = data1[['data','year','state','quarter']]
df = data1
df['name'] = df['data'].apply(lambda x:x['name'])
df['type'] = df['data'].apply(lambda x:x['metric'][0]['type'])
df['count'] = df['data'].apply(lambda x:x['metric'][0]['count'])
df['amount'] = df['data'].apply(lambda x:round(x['metric'][0]['amount']))
ani12= df.iloc[:,1:]



df1 = pd.read_json("C:/Users/basha/OneDrive/Desktop/transaction/hover/country/india/state/andaman-_-nicobar-islands/2021/1.json")
data1 = df1.iloc[0].to_json()
data1 = pd.read_json(data1)
data1['year']=2021
data1["state"]="Andaman-_-nicobar-islands"
data1["quarter"]="q1"
data1 = data1[['data','year','state','quarter']]
df = data1
df['name'] = df['data'].apply(lambda x:x['name'])
df['type'] = df['data'].apply(lambda x:x['metric'][0]['type'])
df['count'] = df['data'].apply(lambda x:x['metric'][0]['count'])
df['amount'] = df['data'].apply(lambda x:round(x['metric'][0]['amount']))
ani13 = df.iloc[:,1:]


df1 = pd.read_json("C:/Users/basha/OneDrive/Desktop/transaction/hover/country/india/state/andaman-_-nicobar-islands/2021/2.json")
data1 = df1.iloc[0].to_json()
data1 = pd.read_json(data1)
data1['year']=2021
data1["state"]="Andaman-_-nicobar-islands"
data1["quarter"]="q2"
data1 = data1[['data','year','state','quarter']]
df = data1
df['name'] = df['data'].apply(lambda x:x['name'])
df['type'] = df['data'].apply(lambda x:x['metric'][0]['type'])
df['count'] = df['data'].apply(lambda x:x['metric'][0]['count'])
df['amount'] = df['data'].apply(lambda x:round(x['metric'][0]['amount']))
ani14= df.iloc[:,1:]


df1 = pd.read_json("C:/Users/basha/OneDrive/Desktop/transaction/hover/country/india/state/andaman-_-nicobar-islands/2021/3.json")
data1 = df1.iloc[0].to_json()
data1 = pd.read_json(data1)
data1['year']=2021
data1["state"]="Andaman-_-nicobar-islands"
data1["quarter"]="q3"
data1 = data1[['data','year','state','quarter']]
df = data1
df['name'] = df['data'].apply(lambda x:x['name'])
df['type'] = df['data'].apply(lambda x:x['metric'][0]['type'])
df['count'] = df['data'].apply(lambda x:x['metric'][0]['count'])
df['amount'] = df['data'].apply(lambda x:round(x['metric'][0]['amount']))
ani15 = df.iloc[:,1:]


df1 = pd.read_json("C:/Users/basha/OneDrive/Desktop/transaction/hover/country/india/state/andaman-_-nicobar-islands/2021/4.json")
data1 = df1.iloc[0].to_json()
data1 = pd.read_json(data1)
data1['year']=2021
data1["state"]="Andaman-_-nicobar-islands"
data1["quarter"]="q4"
data1 = data1[['data','year','state','quarter']]
df = data1
df['name'] = df['data'].apply(lambda x:x['name'])
df['type'] = df['data'].apply(lambda x:x['metric'][0]['type'])
df['count'] = df['data'].apply(lambda x:x['metric'][0]['count'])
df['amount'] = df['data'].apply(lambda x:round(x['metric'][0]['amount']))
ani16= df.iloc[:,1:]


df1 = pd.read_json("C:/Users/basha/OneDrive/Desktop/transaction/hover/country/india/state/andaman-_-nicobar-islands/2022/1.json")
data1 = df1.iloc[0].to_json()
data1 = pd.read_json(data1)
data1['year']=2022
data1["state"]="Andaman-_-nicobar-islands"
data1["quarter"]="q1"
data1 = data1[['data','year','state','quarter']]
df = data1
df['name'] = df['data'].apply(lambda x:x['name'])
df['type'] = df['data'].apply(lambda x:x['metric'][0]['type'])
df['count'] = df['data'].apply(lambda x:x['metric'][0]['count'])
df['amount'] = df['data'].apply(lambda x:round(x['metric'][0]['amount']))
ani17 = df.iloc[:,1:]

dz=pd.concat([ani1,ani2,ani3,ani4,ani5,ani6,ani7,ani8,ani9,ani10,ani11,ani12,ani13,ani14,ani15,ani16,ani17],axis=0)
dz.to_csv("C:/Users/basha/OneDrive/Desktop/ Andaman-_-nicobar-islands.csv")
